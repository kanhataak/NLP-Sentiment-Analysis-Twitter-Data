# %% [markdown]
# # Tweeter dataset ---> Fixing Imbalanced Dataset

# %% [markdown]
# #  Context
# The objective of this task is to detect hate speech in tweets. For the sake of simplicity, we say a tweet contains hate speech if it has a racist or sexist sentiment associated with it. So, the task is to classify racist or sexist tweets from other tweets.
#
# Formally, given a training sample of tweets and labels, where label '1' denotes the tweet is racist/sexist and label '0' denotes the tweet is not racist/sexist, your objective is to predict the labels on the test dataset.

# %% [markdown]
# # Data exploration
#     is the initial step in data analysis, where users explore a large data set in an unstructured way to uncover initial patterns, characteristics, and points of interest. This process isn’t meant to reveal every bit of information a dataset holds, but rather to help create a broad picture of important trends and major points to study in greater detail.
# https://towardsdatascience.com/what-to-do-when-your-classification-dataset-is-imbalanced-6af031b12a36

# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
import nltk
import string
import warnings

from wordcloud import WordCloud, STOPWORDS

from sklearn.naive_bayes import BernoulliNB  # MultinomialNB,GaussianNB

from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# # Train Data Load

# %%
df_train=pd.read_csv("clean_train_tweet.csv")
df_test=pd.read_csv("clean_test_tweet.csv")

# %%
df_train.head()
# Out:
#    label                                        clean_tweet
# 0      0  user father dysfunct selfish drag kid dysfunct...
# 1      0  user user thank lyft credit cant use caus dont...
# 2      0                                     bihday majesti
# 3      0                        model love u take u time ur
# 4      0                            factsguid societi motiv

# %%
df_train.shape
# Out:
# (31962, 2)

# %%
df_train.isnull().sum()
# Out:
# label           0
# clean_tweet    11
# dtype: int64

# %% [markdown]
# ### Drop the missing Row "NaN Value"  in Train data

# %%
df_finel=df_train.dropna(axis=0)

# %%
df_finel.shape
# Out:
# (31951, 2)

# %%
df_finel.isnull().sum()
# Out:
# label          0
# clean_tweet    0
# dtype: int64

# %%
df_finel.head()
# Out:
#    label                                        clean_tweet
# 0      0  user father dysfunct selfish drag kid dysfunct...
# 1      0  user user thank lyft credit cant use caus dont...
# 2      0                                     bihday majesti
# 3      0                        model love u take u time ur
# 4      0                            factsguid societi motiv

# %% [markdown]
# ###  Data Exploratory Data Analysis  ---> Racist/sexist and Not Racist/sexist

# %%
sn.countplot(df_finel.label)
plt.xlabel('Label')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Data is completely imbalanced

# %% [markdown]
# # How many Positive and Nagitive tweets

# %%
# Class distribution in this data seems to be imbalanced 

nagitive = df_finel[df_finel['label']==1]

positive = df_finel[df_finel['label']==0]

# %%
print(f'Negitive: {nagitive.shape}\n Positive: {positive.shape}')
# Out:
# Negitive: (2241, 2)
#  Positive: (29710, 2)

# %%
# Nagitive tweets...
fetch_one= df_finel.loc[df_finel['label']==1]
fetch_one.count()
# Out:
# label          2241
# clean_tweet    2241
# dtype: int64

# %%
# Positive tweets...
fetch_zero=df_finel.loc[df_finel['label']==0]
fetch_zero.count()
# Out:
# label          29710
# clean_tweet    29710
# dtype: int64

# %%
all_words = " ".join(df_finel.clean_tweet)

# %%
wordcloud = WordCloud(height=1000, width=1000, max_font_size = 110, stopwords=STOPWORDS, background_color='black')
wordcloud = wordcloud.generate(all_words)
plt.figure(figsize = (10,10))
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
positive_words = " ".join(fetch_zero.clean_tweet)
negitive_words = " ".join(fetch_one.clean_tweet)

# %%
wordcloud = WordCloud(height=1000, width=1000, max_font_size = 110, stopwords=STOPWORDS, background_color='black')
wordcloud = wordcloud.generate(positive_words)
plt.figure(figsize = (10,8))
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis('off')

wordcloud = WordCloud(height=1000, width=1000, max_font_size = 110, stopwords=STOPWORDS, background_color='black')
wordcloud = wordcloud.generate(negitive_words)
plt.figure(figsize = (10,8))
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
# the frequency of words within a text
from nltk import FreqDist
# from nltk import FreqDist
word_freq = FreqDist(list(" ".join(df_finel.clean_tweet).split())).most_common(15)
word_freq
# Out:
# [('user', 17515),
#  ('love', 3146),
#  ('day', 2817),
#  ('happi', 2091),
#  ('amp', 1609),
#  ('thank', 1543),
#  ('get', 1257),
#  ('time', 1239),
#  ('u', 1150),
#  ('go', 1146),
#  ('im', 1144),
#  ('life', 1143),
#  ('like', 1115),
#  ('today', 1088),
#  ('posit', 991)]

# %%
contractions = {"ain't": "am not", "aren't": "are not", "can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not", "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not", "he'd": "he would", "he'll": "he will", "he's": "he is", "how'd": "how did", "i'd": "I would", "i'll": "I will", "i'm": "I am", "i've": "I have", "isn't": "is not", "it'd": "it would", "it'll": "it will", "it's": "it is", "let's": "let us", "ma'am": "madam", "might've": "might have", "must've": "must have", "mustn't": "must not", "needn't": "need not", "o'clock": "of the clock", "shan't": "shall not", "she'd": "she would", "she'll": "she will", "she's": "she is", "should've": "should have", "shouldn't": "should not", "that'd": "that would", "that's": "that is", "there's": "there is", "they'll": "they will", "they're": "they are", "they've": "they have", "wasn't": "was not", "we'd": "we would", "we'll": "we will", "we're": "we are", "we've": "we have", "weren't": "were not", "what'll": "what will", "what's": "what is", "when's": "when is", "where's": "where is", "who'll": "who will", "who's": "who is", "why's": "why is", "won't": "will not", "would've": "would have", "wouldn't": "would not", "y'all": "you all", "you'd": "you would", "you'll": "you will", "you're": "you are", "you've": "you have", "how's": "how is", "aint": "am not", "arent": "are not", "cant": "cannot", "couldve": "could have", "couldnt": "could not", "didnt": "did not", "doesnt": "does not", "dont": "do not", "hadnt": "had not", "hasnt": "has not", "havent": "have not", "im": "I am", "ive": "I have", "isnt": "is not", "itll": "it will", "lets": "let us", "maam": "madam", "mightve": "might have", "mustve": "must have", "mustnt": "must not", "neednt": "need not", "shant": "shall not", "shouldve": "should have", "shouldnt": "should not", "thats": "that is", "theyll": "they will", "theyre": "they are", "theyve": "they have", "wasnt": "was not", "werent": "were not", "whatll": "what will", "whats": "what is", "wholl": "who will", "wont": "will not", "wouldve": "would have", "wouldnt": "would not", "yall": "you all", "youll": "you will", "youre": "you are", "youve": "you have", "hows": "how is"}

# %%
y =df_finel.label.values

# %%
x = df_finel.clean_tweet.values

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, stratify=y, random_state=42,shuffle=True)

# %%
from sklearn.feature_extraction.text import CountVectorizer
# create obj countvectoer
cv= CountVectorizer()
cv=CountVectorizer(stop_words="english")

# %%
x_traincv=cv.fit_transform(x_train)
x_testcv =cv.transform(x_test)

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
model=MultinomialNB()
model.fit(x_traincv, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
model2 = BernoulliNB()
model2.fit(x_traincv, y_train)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
yp2=model2.predict(x_testcv)

# %%
yp2
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
cm= confusion_matrix(y_test,yp2)
cm
# Out:
# array([[7424,    4],
#        [ 446,  114]], dtype=int64)

# %%
model2.score(x_traincv,y_train)
# Out:
# 0.9520510787464007

# %%
yp=model.predict(x_testcv)

# %%
yp
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.score(x_traincv,y_train)
# Out:
# 0.9695780995701707

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
accuracy_score(y_test,yp)
# Out:
# 0.9588132198297447

# %%
cm= confusion_matrix(y_test,yp)
cm
# Out:
# array([[7380,   48],
#        [ 281,  279]], dtype=int64)

# %% [markdown]
# # Test Data load

# %%
df_test.head(2)
# Out:
#       id                                   clean_test_tweet
# 0  31963  studiolif aislif requir passion dedic willpow ...
# 1  31964  user white supremacist want everyon see new bi...

# %%
df_test.columns
# Out:
# Index(['id', 'clean_test_tweet'], dtype='object')

# %%
df_test.shape
# Out:
# (17197, 2)

# %%
df_test.isnull().sum()
# Out:
# id                  0
# clean_test_tweet    8
# dtype: int64

# %% [markdown]
# ### Drop the missing rows "Nan" in test data set

# %%
test_df=df_test.dropna(axis=0)

# %%
test_df.shape
# Out:
# (17189, 2)

# %%
test_df.isnull().sum()
# Out:
# id                  0
# clean_test_tweet    0
# dtype: int64

# %%
# cv=CountVectorizer(stop_words="english")

# %%
x_train = df_finel.clean_tweet
y_train = df_finel.label

# %%
cv = CountVectorizer()

# %%
x_trainCV=cv.fit_transform(x_train)

# %% [markdown]
# ### Training the Model
# The data that was created using the above code is used to train the model

# %%
nb_model = BernoulliNB()
nb_model.fit(x_trainCV,y_train)
# Out:
# BernoulliNB(alpha=1.0, binarize=0.0, class_prior=None, fit_prior=True)

# %%
nb_model.score(x_trainCV,y_train)
# Out:
# 0.9558386278989703

# %% [markdown]
# # Test model

# %%
x_test=test_df.clean_test_tweet
x_testCV=cv.transform(x_test)

# %%
yp=nb_model.predict(x_testCV)

# %%
yp
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
# from sklearn.metrics import confusion_matrix
# confusion_matrix(x_testCV,yp)

# %%
random_subset = df_train.label.sample(n=4000)

# %%
random_subset.head()
# Out:
# 18415    0
# 28273    0
# 23690    0
# 7883     0
# 1905     0
# Name: label, dtype: int64

# %%
len(random_subset)
# Out:
# 4000

# %%
len(df_train.label)
# Out:
# 31962

# %%
df_train['label'].nunique()
# Out:
# 2

# %%
df_train['label'].count()
# Out:
# 31962

# %%
df_train['label'].size
# Out:
# 31962

# %%
cou=df_train['label'].value_counts()

# %%
cou
# Out:
# 0    29720
# 1     2242
# Name: label, dtype: int64

# %%
random_subset.value_counts()
# Out:
# 0    3697
# 1     303
# Name: label, dtype: int64
